# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Use seaborn style
plt.style.use('seaborn')

# Load your lap time data
file_list = ['data/real_track_LSTM_lap_times.npy', 'data/real_track_CNN_lap_times.npy', 'data/real_track_MLP_lap_times.npy']  # Add more filenames as needed
data = [np.load(file) for file in file_list]
num_laps = [len(d) for d in data]  # Calculate the number of laps for each robot
labels = [f'LSTM\n({num_laps[0]} laps)', f'CNN\n({num_laps[1]} laps)', f'MLP\n({num_laps[2]} laps)']  # Add labels with number of laps

# Create a box plot with different colors
colors = ['skyblue', 'lightgreen', 'lightcoral']  # Customize colors for each box
plt.figure(figsize=(8, 6))  # Set the figure size as needed
box = plt.boxplot(data, patch_artist=True)

# Customize the colors of the boxes
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

# Set labels and title
plt.title('Real-Track in Simulation, 30 seconds time trial')
plt.ylabel('Time in Seconds')
plt.xticks([1, 2, 3], labels)  # Set x-tick labels to match data labels
plt.grid(True)  # Adds a grid for better readability

plt.show()
# Out:
# /tmp/ipykernel_350455/758675504.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Use seaborn style
plt.style.use('seaborn')

# Load your lap time data
file_list = ['data/test_track_1_MLP_lap_times.npy', 'data/test_track_1_LSTM_lap_times.npy', 'data/test_track_1_CNN_lap_times.npy']  # Add more filenames as needed
data = [np.load(file) for file in file_list]
num_laps = [len(d) for d in data]  # Calculate the number of laps for each robot
labels = [f'LSTM\n({num_laps[0]} laps)', f'CNN\n({num_laps[1]} laps)', f'MLP\n({num_laps[2]} laps)']  # Add labels with number of laps

# Create a violin plot with different colors
colors = ['skyblue', 'lightgreen', 'lightcoral']  # Customize colors for each violin
plt.figure(figsize=(6, 6))  # Set the figure size as needed
plots = plt.violinplot(data, vert=True, showmedians=True, showextrema=False, widths=0.8)

# Customize the colors of the violins
for i, (violin, color) in enumerate(zip(plots['bodies'], colors)):
    violin.set_facecolor(color)
    violin.set_edgecolor('black')  # Set the edge color if needed
    violin.set_alpha(0.6)  # Set transparency for better visibility

# Customize median lines
plots['cmedians'].set_colors(colors)
plots['cmedians'].set_linewidth(3)

# Set labels and title
plt.title('Real-Track in Simulation, 30 seconds time trial')
plt.ylabel('Time in Seconds')
plt.xticks([1, 2, 3], labels)  # Set x-tick labels to match data labels
plt.grid(True)  # Adds a grid for better readability

plt.show()
# Out:
# /tmp/ipykernel_350455/3882207216.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Use seaborn style
plt.style.use('seaborn')

# Load your lap time data
file_list = ['data/test_track_1_MLP_lap_times.npy', 'data/test_track_1_LSTM_lap_times.npy', 'data/test_track_1_CNN_lap_times.npy']  # Add more filenames as needed
data = [np.load(file) for file in file_list]
num_laps = [len(d) for d in data]  # Calculate the number of laps for each robot
labels = [f'MLP\n({num_laps[0]} laps)', f'LSTM\n({num_laps[1]} laps)', f'CNN\n({num_laps[2]} laps)']  # Add labels with number of laps

# Create a violin plot with different colors
colors = [ '#e41a1c', '#4daf4a', '#377eb8']  # Colorblind-friendly palette


plt.figure(figsize=(4, 6))  # Set the figure size as needed
plots = plt.violinplot(data, showmedians=True, showextrema=True, widths=0.5)

# Customize the colors of the violins
for i, (violin, color) in enumerate(zip(plots['bodies'], colors)):
    violin.set_facecolor(color)
    violin.set_edgecolor(color)
    violin.set_alpha(0.6)  # Set transparency for better visibility

# Customize median lines
plots['cmedians'].set_color(colors)
plots['cmedians'].set_linewidth(2)
plots['cmaxes'].set_color(colors)
plots['cmins'].set_color(colors)
plots['cbars'].set_color(colors)

# Set labels and title
plt.title('Test-Track 1 Lap Times')
plt.ylabel('Lap time (s)')
plt.xticks([1, 2, 3], labels)  # Set x-tick labels to match data labels
plt.grid(True)  # Adds a grid for better readability

plt.show()
# Out:
# /tmp/ipykernel_350455/3112739566.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Use seaborn style
plt.style.use('seaborn')

# Load your lap time data
file_list = ['data/test_track_2_MLP_lap_times.npy', 'data/test_track_2_LSTM_lap_times.npy', 'data/test_track_2_CNN_lap_times.npy']  # Add more filenames as needed
data = [np.load(file) for file in file_list]

data[2][0] = data[2][1] # The first was due to a bug in the initialization

num_laps = [len(d) for d in data]  # Calculate the number of laps for each robot
labels = [f'MLP\n({num_laps[0]} laps)', f'LSTM\n({num_laps[1]} laps)', f'CNN\n({num_laps[2]} laps)']  # Add labels with number of laps

# Create a violin plot with different colors
colors = [ '#e41a1c', '#4daf4a', '#377eb8']  # Colorblind-friendly palette


plt.figure(figsize=(4, 6))  # Set the figure size as needed
plots = plt.violinplot(data, showmedians=True, showextrema=True, widths=0.5)

# Customize the colors of the violins
for i, (violin, color) in enumerate(zip(plots['bodies'], colors)):
    violin.set_facecolor(color)
    violin.set_edgecolor(color)
    violin.set_alpha(0.6)  # Set transparency for better visibility

# Customize median lines
plots['cmedians'].set_color(colors)
plots['cmedians'].set_linewidth(2)
plots['cmaxes'].set_color(colors)
plots['cmins'].set_color(colors)
plots['cbars'].set_color(colors)

# Set labels and title
plt.title('Test-Track 2 Lap Times')
plt.ylabel('Lap time (s)')
plt.xticks([1, 2, 3], labels)  # Set x-tick labels to match data labels
plt.grid(True)  # Adds a grid for better readability

plt.show()
# Out:
# /tmp/ipykernel_350455/1156174412.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Use seaborn style
plt.style.use('seaborn')

# Load your lap time data
file_list = ['data/test_track_3_MLP_lap_times.npy', 'data/test_track_3_LSTM_lap_times.npy', 'data/test_track_3_CNN_lap_times.npy']  # Add more filenames as needed
data = [np.load(file) for file in file_list]
num_laps = [len(d) for d in data]  # Calculate the number of laps for each robot
labels = [f'MLP\n({num_laps[0]} laps)', f'LSTM\n({num_laps[1]} laps)', f'CNN\n({num_laps[2]} laps)']  # Add labels with number of laps

# Create a violin plot with different colors
colors = [ '#e41a1c', '#4daf4a', '#377eb8']  # Colorblind-friendly palette


plt.figure(figsize=(4, 6))  # Set the figure size as needed
plots = plt.violinplot(data, showmedians=True, showextrema=True, widths=0.5)

# Customize the colors of the violins
for i, (violin, color) in enumerate(zip(plots['bodies'], colors)):
    violin.set_facecolor(color)
    violin.set_edgecolor(color)
    violin.set_alpha(0.6)  # Set transparency for better visibility

# Customize median lines
plots['cmedians'].set_color(colors)
plots['cmedians'].set_linewidth(2)
plots['cmaxes'].set_color(colors)
plots['cmins'].set_color(colors)
plots['cbars'].set_color(colors)

# Set labels and title
plt.title('Test-Track 3 Lap Times')
plt.ylabel('Lap time (s)')
plt.xticks([1, 2, 3], labels)  # Set x-tick labels to match data labels
plt.grid(True)  # Adds a grid for better readability

plt.show()
# Out:
# /tmp/ipykernel_350455/582912454.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Use seaborn style
plt.style.use('seaborn')

# Load your lap time data
file_list = ['data/train_track_1_MLP_lap_times.npy', 'data/train_track_1_LSTM_lap_times.npy', 'data/train_track_1_CNN_lap_times.npy']

data = [np.load(file) for file in file_list]
num_laps = [len(d) for d in data]  # Calculate the number of laps for each robot
labels = [f'MLP\n({num_laps[0]} laps)', f'LSTM\n({num_laps[1]} laps)', f'CNN\n({num_laps[2]} laps)']  # Add labels with number of laps

# Create a violin plot with different colors
colors = [ '#e41a1c', '#4daf4a', '#377eb8']  # Colorblind-friendly palette


plt.figure(figsize=(4, 6))  # Set the figure size as needed
plots = plt.violinplot(data, showmedians=True, showextrema=True, widths=0.5)

# Customize the colors of the violins
for i, (violin, color) in enumerate(zip(plots['bodies'], colors)):
    violin.set_facecolor(color)
    violin.set_edgecolor(color)
    violin.set_alpha(0.6)  # Set transparency for better visibility

# Customize median lines
plots['cmedians'].set_color(colors)
plots['cmedians'].set_linewidth(2)
plots['cmaxes'].set_color(colors)
plots['cmins'].set_color(colors)
plots['cbars'].set_color(colors)

# Set labels and title
plt.title('Train-Track 1 Lap Times')
plt.ylabel('Lap time (s)')
plt.xticks([1, 2, 3], labels)  # Set x-tick labels to match data labels
plt.grid(True)  # Adds a grid for better readability

plt.show()
# Out:
# /tmp/ipykernel_350455/2635814265.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Use seaborn style
plt.style.use('seaborn')

# Load your lap time data
file_list = ['data/train_track_3_MLP_lap_times.npy', 'data/train_track_3_LSTM_lap_times.npy', 'data/train_track_3_CNN_lap_times.npy']

data = [np.load(file) for file in file_list]
num_laps = [len(d) for d in data]  # Calculate the number of laps for each robot
labels = [f'MLP\n({num_laps[0]} laps)', f'LSTM\n({num_laps[1]} laps)', f'CNN\n({num_laps[2]} laps)']  # Add labels with number of laps

# Create a violin plot with different colors
colors = [ '#e41a1c', '#4daf4a', '#377eb8']  # Colorblind-friendly palette


plt.figure(figsize=(4, 6))  # Set the figure size as needed
plots = plt.violinplot(data, showmedians=True, showextrema=True, widths=0.5)

# Customize the colors of the violins
for i, (violin, color) in enumerate(zip(plots['bodies'], colors)):
    violin.set_facecolor(color)
    violin.set_edgecolor(color)
    violin.set_alpha(0.6)  # Set transparency for better visibility

# Customize median lines
plots['cmedians'].set_color(colors)
plots['cmedians'].set_linewidth(2)
plots['cmaxes'].set_color(colors)
plots['cmins'].set_color(colors)
plots['cbars'].set_color(colors)

# Set labels and title
plt.title('Train-Track 1 Lap Times')
plt.ylabel('Lap time (s)')
plt.xticks([1, 2, 3], labels)  # Set x-tick labels to match data labels
plt.grid(True)  # Adds a grid for better readability

plt.show()
# Out:
# /tmp/ipykernel_350455/3749535073.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import numpy as np
import matplotlib.pyplot as plt


# Use seaborn style
plt.style.use('seaborn')

plt.rcParams.update({
    'font.size': 24,
    'axes.titlesize': 16,     # Font size for titles
    'axes.labelsize': 16,     # Font size for x and y labels
    'xtick.labelsize': 12,    # Font size for x tick labels
    'ytick.labelsize': 12,    # Font size for y tick labels
    'legend.fontsize': 12     # Font size for legend
})



# Define file lists and titles for each plot
file_lists = [
    ['data/test_track_1_MLP_lap_times.npy', 'data/test_track_1_LSTM_lap_times.npy', 'data/test_track_1_CNN_lap_times.npy'],
    ['data/test_track_2_MLP_lap_times.npy', 'data/test_track_2_LSTM_lap_times.npy', 'data/test_track_2_CNN_lap_times.npy'],
    ['data/test_track_3_MLP_lap_times.npy', 'data/test_track_3_LSTM_lap_times.npy', 'data/test_track_3_CNN_lap_times.npy']
]
titles = [
    'Test Track 1 Lap Times',
    'Test Track 2 Lap Times',
    'Test Track 3 Lap Times'
]
colors = ['#e41a1c', '#4daf4a', '#377eb8']  # Colorblind-friendly palette

fig, axs = plt.subplots(1, 3, figsize=(18, 6))  # Create a 1x3 grid of subplots

for ax, file_list, title in zip(axs, file_lists, titles):
    # Load data
    data = [np.load(file) for file in file_list]
    
    # Adjust for known data issue
    # if 'test_track_2' in file_list[0]:
    #     data[2][0] = data[2][1]  # Adjust the first entry for CNN in test track 2

    num_laps = [len(d) for d in data]  # Calculate the number of laps for each robot
    labels = [f'MLP\n({num_laps[0]} laps)', f'LSTM\n({num_laps[1]} laps)', f'CNN\n({num_laps[2]} laps)']  # Add labels with number of laps

    # Create a violin plot
    plots = ax.violinplot(data, showmedians=True, showextrema=True, widths=0.5)

    # Customize the colors of the violins
    for i, (violin, color) in enumerate(zip(plots['bodies'], colors)):
        violin.set_facecolor(color)
        violin.set_edgecolor(color)
        violin.set_alpha(0.6)  # Set transparency for better visibility

    # Customize median lines
    plots['cmedians'].set_color(colors)
    plots['cmedians'].set_linewidth(2)
    plots['cmaxes'].set_color(colors)
    plots['cmins'].set_color(colors)
    plots['cbars'].set_color(colors)

    # Set labels and title
    ax.set_title(title)
    ax.set_xticks([1, 2, 3])
    ax.set_xticklabels(labels)  # Set x-tick labels to match data labels
    ax.grid(True)  # Adds a grid for better readability

# Set y-axis label only for the leftmost plot
axs[0].set_ylabel('Lap time (s)')
for ax in axs[1:]:
    ax.set_ylabel('')

# Add a title for the entire figure
plt.suptitle('Lap Time Comparison Across Different Tracks and Models for Time-Trail of 5 Minutes', fontsize=20)

# Adjust layout for better appearance
plt.tight_layout()
plt.savefig('images/lap_times.svg', format='svg')
plt.show()
# Out:
# /tmp/ipykernel_350455/3752649936.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Use seaborn style
plt.style.use('seaborn')

plt.rcParams.update({
    'font.size': 24,
    'axes.titlesize': 16,     # Font size for titles
    'axes.labelsize': 16,     # Font size for x and y labels
    'xtick.labelsize': 12,    # Font size for x tick labels
    'ytick.labelsize': 12,    # Font size for y tick labels
    'legend.fontsize': 12     # Font size for legend
})

# Define file lists and titles for each plot
file_lists = [
    ['data/test_track_1_MLP_lap_times.npy', 'data/test_track_1_LSTM_lap_times.npy', 'data/test_track_1_CNN_lap_times.npy'],
    ['data/test_track_2_MLP_lap_times.npy', 'data/test_track_2_LSTM_lap_times.npy', 'data/test_track_2_CNN_lap_times.npy'],
    ['data/test_track_3_MLP_lap_times.npy', 'data/test_track_3_LSTM_lap_times.npy', 'data/test_track_3_CNN_lap_times.npy']
]
titles = [
    'Test Track 1 Lap Times',
    'Test Track 2 Lap Times',
    'Test Track 3 Lap Times'
]
colors = ['#e41a1c', '#4daf4a', '#377eb8']  # Colorblind-friendly palette

fig, axs = plt.subplots(1, 3, figsize=(18, 8))  # Create a 1x3 grid of subplots

average_lap_times = []

for ax, file_list, title in zip(axs, file_lists, titles):
    # Load data
    data = [np.load(file) for file in file_list]

    # Calculate the average lap time for each model
    avg_times = [np.mean(d) for d in data]
    average_lap_times.append(avg_times)

    num_laps = [len(d) for d in data]  # Calculate the number of laps for each robot
    labels = [f'MLP\n({num_laps[0]} laps)', f'LSTM\n({num_laps[1]} laps)', f'CNN\n({num_laps[2]} laps)']  # Add labels with number of laps

    # Create a violin plot
    plots = ax.violinplot(data, showmedians=True, showextrema=True, widths=0.5)

    # Customize the colors of the violins
    for i, (violin, color) in enumerate(zip(plots['bodies'], colors)):
        violin.set_facecolor(color)
        violin.set_edgecolor(color)
        violin.set_alpha(0.6)  # Set transparency for better visibility

    # Customize median lines
    plots['cmedians'].set_color(colors)
    plots['cmedians'].set_linewidth(2)
    plots['cmaxes'].set_color(colors)
    plots['cmins'].set_color(colors)
    plots['cbars'].set_color(colors)

    # Set labels and title
    ax.set_title(title)
    ax.set_xticks([1, 2, 3])
    ax.set_xticklabels(labels)  # Set x-tick labels to match data labels
    ax.grid(True)  # Adds a grid for better readability


# Set y-axis label only for the leftmost plot
axs[0].set_ylabel('Lap time (s)')
for ax in axs[1:]:
    ax.set_ylabel('')


# Adjust layout for better appearance
plt.tight_layout()
plt.savefig('images/lap_times.svg', format='svg')
plt.show()

# Print average lap times
print("Average Lap Times:")
for i, avg_times in enumerate(average_lap_times):
    print(f"Test Track {i+1}: MLP - {avg_times[0]:.2f}, LSTM - {avg_times[1]:.2f}, CNN - {avg_times[2]:.2f}")
# Out:
# /tmp/ipykernel_350455/3322740130.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# Average Lap Times:
# Test Track 1: MLP - 13.92, LSTM - 13.66, CNN - 14.15
# Test Track 2: MLP - 10.07, LSTM - 10.58, CNN - 9.97
# Test Track 3: MLP - 10.04, LSTM - 9.97, CNN - 10.40

# %%
import numpy as np
import matplotlib.pyplot as plt

# Use seaborn style
plt.style.use('seaborn')

plt.rcParams.update({
    'font.size': 24,
    'axes.titlesize': 16,     # Font size for titles
    'axes.labelsize': 16,     # Font size for x and y labels
    'xtick.labelsize': 12,    # Font size for x tick labels
    'ytick.labelsize': 12,    # Font size for y tick labels
    'legend.fontsize': 12     # Font size for legend
})

file_lists = [
    ['data/train_track_1_MLP_lap_times.npy', 'data/train_track_1_LSTM_lap_times.npy', 'data/train_track_1_CNN_lap_times.npy'],
    [[15, 30.4], 'data/train_track_2_LSTM_lap_times.npy', [15.47, 18.375, 18.55, 17.67]],
    ['data/train_track_3_MLP_lap_times.npy', [11.94, 12.27, 12.17, 12.19, 12.25], 'data/train_track_3_CNN_lap_times.npy']
]

titles = [
    'Test Track 1 Lap Times',
    'Test Track 2 Lap Times',
    'Test Track 3 Lap Times'
]
colors = ['#e41a1c', '#4daf4a', '#377eb8']  # Colorblind-friendly palette

fig, axs = plt.subplots(1, 3, figsize=(18, 8))  # Create a 1x3 grid of subplots

average_lap_times = []

for ax, file_list, title in zip(axs, file_lists, titles):
    # Load data, handle lists and file paths
    data = []
    for item in file_list:
        if isinstance(item, str):
            data.append(np.load(item))
        else:
            data.append(np.array(item))

    # Calculate the average lap time for each model
    avg_times = [np.mean(d) for d in data]
    average_lap_times.append(avg_times)

    num_laps = [len(d) for d in data]  # Calculate the number of laps for each robot
    labels = [f'MLP\n({num_laps[0]} laps)', f'LSTM\n({num_laps[1]} laps)', f'CNN\n({num_laps[2]} laps)']  # Add labels with number of laps

    # Create a violin plot
    plots = ax.violinplot(data, showmedians=True, showextrema=True, widths=0.5)

    # Customize the colors of the violins
    for i, (violin, color) in enumerate(zip(plots['bodies'], colors)):
        violin.set_facecolor(color)
        violin.set_edgecolor(color)
        violin.set_alpha(0.6)  # Set transparency for better visibility

    # Customize median lines
    for partname in ('cmedians', 'cmaxes', 'cmins', 'cbars'):
        vp = plots[partname]
        vp.set_color(colors)
        vp.set_linewidth(2)

    # Set labels and title
    ax.set_title(title)
    ax.set_xticks([1, 2, 3])
    ax.set_xticklabels(labels)  # Set x-tick labels to match data labels
    ax.grid(True)  # Adds a grid for better readability


# Set y-axis label only for the leftmost plot
axs[0].set_ylabel('Lap time (s)')
for ax in axs[1:]:
    ax.set_ylabel('')


# Adjust layout for better appearance
plt.tight_layout()
plt.savefig('images/lap_times.svg', format='svg')
plt.show()

# Print average lap times
print("Average Lap Times:")
for i, avg_times in enumerate(average_lap_times):
    print(f"Test Track {i+1}: MLP - {avg_times[0]:.2f}, LSTM - {avg_times[1]:.2f}, CNN - {avg_times[2]:.2f}")
# Out:
# /tmp/ipykernel_350455/2270750743.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# Average Lap Times:
# Test Track 1: MLP - 14.75, LSTM - 14.53, CNN - 14.41
# Test Track 2: MLP - 22.70, LSTM - 14.53, CNN - 17.52
# Test Track 3: MLP - 11.92, LSTM - 12.16, CNN - 12.06

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Rewards data
rewards = {
    'Test Track 1': [1014.747, 1025.714, 1012.967],
    'Test Track 2': [1023.404, 970.626, 1033.112],
    'Test Track 3': [1114.281, 1108.968, 1089.495]
}

# Average lap times data
lap_times = {
    'Test Track 1': [13.92, 13.66, 14.15],
    'Test Track 2': [10.07, 10.58, 9.97],
    'Test Track 3': [10.04, 9.97, 10.40]
}

models = ['MLP', 'LSTM', 'CNN']
colors = ['#e41a1c', '#4daf4a', '#377eb8']  # Colorblind-friendly palette

# Set up the plot
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot data and linear regression for each test track
handles = []
labels = []
for ax, (track, reward_data) in zip(axs, rewards.items()):
    lap_time_data = lap_times[track]
    
    # Scatter plot and linear regression for each model
    for i, model in enumerate(models):
        scatter = ax.scatter(reward_data[i], lap_time_data[i], color=colors[i], label=model, s=100)
        handles.append(scatter)
        labels.append(model)
        
        # Linear regression
        slope, intercept, r_value, p_value, std_err = linregress(reward_data, lap_time_data)
        line = slope * np.array(reward_data) + intercept
        ax.plot(reward_data, line, color='black', linestyle='--', linewidth=0.5, alpha=0.5)
    
    # Display correlation coefficient and p-value
    r_value, p_value = linregress(reward_data, lap_time_data)[2:4]
    # ax.text(0.80, 0.95, f'R = {r_value:.2f}\nP = {p_value:.2e}\na = {slope:.2f}\nb = {intercept:.2f}', 
    #         transform=ax.transAxes, fontsize=12, verticalalignment='top', 
    #         bbox=dict(boxstyle='round,pad=0.5', alpha=0.1))
    
    # Set labels and title
    ax.set_title(track)
    if ax == axs[0]:
        ax.set_ylabel('Average Lap Time (s)')
    if ax == axs[1]:
        ax.set_xlabel('Final Accumulated Reward')

# Adjust layout for better appearance
plt.tight_layout(rect=[0, 0.1, 1, 0.95])

# Add a legend below all subplots
fig.legend(handles[:3], labels[:3], loc='lower center', bbox_to_anchor=(0.5, 0.05), ncol=3)

plt.savefig('images/rewards_vs_lap_times_by_track.svg', format='svg')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Rewards data
rewards = {
    'Test Track 1': [1014.747, 1025.714, 1012.967],
    'Test Track 2': [1023.404, 970.626, 1033.112],
    'Test Track 3': [1114.281, 1108.968, 1089.495]
}

# Average lap times data
lap_times = {
    'Test Track 1': [13.92, 13.66, 14.15],
    'Test Track 2': [10.07, 10.58, 9.97],
    'Test Track 3': [10.04, 9.97, 10.40]
}

models = ['MLP', 'LSTM', 'CNN']
colors = ['#e41a1c', '#4daf4a', '#377eb8']  # Colorblind-friendly palette

# Calculate average rewards and lap times for each model
avg_rewards = []
avg_lap_times = []

for model_index in range(len(models)):
    model_rewards = [rewards[track][model_index] for track in rewards]
    model_lap_times = [lap_times[track][model_index] for track in lap_times]
    avg_rewards.append(np.mean(model_rewards))
    avg_lap_times.append(np.mean(model_lap_times))

# Set up the plot
plt.figure(figsize=(10, 6))

# Scatter plot
for i, model in enumerate(models):
    plt.scatter(avg_rewards[i], avg_lap_times[i], color=colors[i], label=model, s=100)

# Linear regression
slope, intercept, r_value, p_value, std_err = linregress(avg_rewards, avg_lap_times)
line = slope * np.array(avg_rewards) + intercept
plt.plot(avg_rewards, line, color='gray', linestyle='--', linewidth=2)

# Display correlation coefficient and p-value
plt.text(0.05, 0.95, f'R={r_value:.2f}\nP={p_value:.2e}', transform=plt.gca().transAxes, fontsize=12,
         verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', alpha=0.1))

# Set labels and title
plt.xlabel('Average Rewards')
plt.ylabel('Average Lap Time (s)')
plt.title('Correlation Between Average Rewards and Average Lap Times Across Models')
plt.legend(loc='upper right')

# Adjust layout and save the plot
plt.tight_layout()
plt.savefig('images/average_rewards_vs_lap_times.svg', format='svg')
plt.show()

# Print average rewards and lap times
print("Average Rewards and Lap Times:")
for i, model in enumerate(models):
    print(f"{model} - Average Reward: {avg_rewards[i]:.2f}, Average Lap Time: {avg_lap_times[i]:.2f}")
# Out:
# Average Rewards and Lap Times:
# MLP - Average Reward: 1050.81, Average Lap Time: 11.34
# LSTM - Average Reward: 1035.10, Average Lap Time: 11.40
# CNN - Average Reward: 1045.19, Average Lap Time: 11.51

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to calculate accumulated rewards and times at lap completion
def get_lap_completion_data(lap_times, rewards, dt):
    lap_completion_rewards = []
    lap_completion_times = []
    total_rewards = np.cumsum(rewards)
    lap_end_indices = np.cumsum(np.ceil(np.array(lap_times) / dt).astype(int))
    
    for idx in lap_end_indices:
        lap_completion_rewards.append(total_rewards[idx - 1])
        lap_completion_times.append(idx * dt)
    
    return lap_completion_times, lap_completion_rewards

# Load lap times data
lap_times = []
for file_list in file_lists:
    track_times = [np.load(file) for file in file_list]
    lap_times.append(track_times)

# Load rewards data
rewards_data = [np.load(file) for file in data_files]

# Iterate over tracks and models
colors = ['b', 'g', 'r']
models = ['MLP', 'LSTM', 'CNN']

for track_idx, track_lap_times in enumerate(lap_times):
    plt.figure(figsize=(10, 6))
    for model_idx, model_lap_times in enumerate(track_lap_times):
        rewards = rewards_data[track_idx * 3 + model_idx]
        lap_completion_times, lap_completion_rewards = get_lap_completion_data(model_lap_times, rewards, dt)
        plt.scatter(lap_completion_times, lap_completion_rewards, label=f'{models[model_idx]}', color=colors[model_idx])
    
    # Plotting
    plt.xlabel('Time (s)')
    plt.ylabel('Accumulated Reward')
    plt.title(f'Accumulated Reward at Lap Completion Times - Track {track_idx + 1}')
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 24
#      21     lap_times.append(track_times)
#      23 # Load rewards data
# ---> 24 rewards_data = [np.load(file) for file in data_files]
#      26 # Iterate over tracks and models
#      27 colors = ['b', 'g', 'r']
#
# NameError: name 'data_files' is not defined
