# %%
# Load the numpy file 
import numpy as np
file_path = 'data/pos_data_no_pen.npy'
pos_data = np.load(file_path)

# Display the data type, shape, and first few elements
print("Data Type:", type(pos_data))
print("Data Shape:", pos_data.shape)
print("First few elements:", pos_data[:10])
# Out:
# Data Type: <class 'numpy.ndarray'>
# Data Shape: (200, 2, 1, 3)
# First few elements: [[[[ 0.0000000e+00  0.0000000e+00  0.0000000e+00]]
#
#   [[ 0.0000000e+00  0.0000000e+00  0.0000000e+00]]]
#
#
#  [[[ 5.0000000e+00  5.0000000e+00  5.0999999e-01]]
#
#   [[ 0.0000000e+00  0.0000000e+00  0.0000000e+00]]]
#
#
#  [[[ 5.0000000e+00  5.0000000e+00  5.0999999e-01]]
#
#   [[ 0.0000000e+00  0.0000000e+00  0.0000000e+00]]]
#
#
#  [[[ 5.0000000e+00  5.0000000e+00  5.0999999e-01]]
#
#   [[ 0.0000000e+00  0.0000000e+00  0.0000000e+00]]]
#
#
#  [[[ 5.0013814e+00  4.9999347e+00  5.0337535e-01]]
#
#   [[-4.7134887e-03  4.0228860e-03 -3.3015570e-01]]]
#
#
#  [[[ 5.0026622e+00  5.0000710e+00  4.9069086e-01]]
#
#   [[-4.9371101e-02  5.4887997e-04 -5.6716895e-01]]]
#
#
#  [[[ 5.0012121e+00  5.0000091e+00  4.7277474e-01]]
#
#   [[-4.8564311e-02  9.5260021e-04 -6.4302903e-01]]]
#
#
#  [[[ 5.0002270e+00  4.9998846e+00  4.4864073e-01]]
#
#   [[-1.5463102e-02  5.8358992e-03 -9.1830337e-01]]]
#
#
#  [[[ 5.0017171e+00  5.0000486e+00  4.1742837e-01]]
#
#   [[-8.0417670e-02  3.5814324e-03 -1.3156517e+00]]]
#
#
#  [[[ 5.0004892e+00  4.9998875e+00  3.8111660e-01]]
#
#   [[-3.5545774e-02  1.1201790e-02 -1.3921163e+00]]]]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the numpy file
file_path = 'data/pos_data_no_pen.npy'
pos_data = np.load(file_path)

# Extract the x and y coordinates
x_values = pos_data[1:,0, 0, 0]
y_values = pos_data[1:,0, 0, 1]

# Create a plot for the (x, y) data
plt.figure(figsize=(10, 6))  # Adjust figure size
plt.plot(x_values, y_values, 'b-', alpha=0.5, label='Position Data')  # 'b-' for a blue line with transparency

# Add labels and a title
plt.xlabel('X Coordinate', fontsize=12)
plt.ylabel('Y Coordinate', fontsize=12)
plt.title('Line Plot of Position Data (x, y)', fontsize=14)

# Add gridlines for better readability
plt.grid(True, linestyle='--', linewidth=0.5)

# Add a legend
plt.legend()

# Draw a starting zone at (5,5)
# Draw a circle with a radius of 0.2 around (5,5)
start_x, start_y = 5, 5
radius = 0.2
circle = plt.Circle((start_x, start_y), radius, color='r', fill=False, linestyle='--', linewidth=2, label='Starting Zone')
plt.gca().add_patch(circle)

# Display the plot
plt.show()

# %%
# Load the numpy file 
file_path = 'data/pos_data_log_pen.npy'
pos_data = np.load(file_path)

# Display the data type, shape, and first few elements
print("Data Type:", type(pos_data))
print("Data Shape:", pos_data.shape)
print("First few elements:", pos_data[:10])
# Out:
# Data Type: <class 'numpy.ndarray'>
# Data Shape: (200, 2, 1, 3)
# First few elements: [[[[ 0.          0.          0.        ]]
#
#   [[ 0.          0.          0.        ]]]
#
#
#  [[[ 5.          5.          0.51      ]]
#
#   [[ 0.          0.          0.        ]]]
#
#
#  [[[ 5.          5.          0.51      ]]
#
#   [[ 0.          0.          0.        ]]]
#
#
#  [[[ 5.          5.          0.51      ]]
#
#   [[ 0.          0.          0.        ]]]
#
#
#  [[[ 4.9918804   4.986416    0.52605176]]
#
#   [[-0.1264832  -0.02255031  1.1457192 ]]]
#
#
#  [[[ 5.002677    5.000427    0.54370576]]
#
#   [[ 0.05763861 -0.23092225  1.3478111 ]]]
#
#
#  [[[ 5.0227637   5.01647     0.5128896 ]]
#
#   [[-0.12126136 -1.1824307   1.2682915 ]]]
#
#
#  [[[ 5.0187235   4.994953    0.46682307]]
#
#   [[-0.47414818 -1.3691063  -0.21747944]]]
#
#
#  [[[ 4.996441    4.9757843   0.45511094]]
#
#   [[-0.78118265 -0.370744   -0.4450633 ]]]
#
#
#  [[[ 4.9938154   4.988384    0.4474961 ]]
#
#   [[-0.11467054 -0.23565131  0.2617425 ]]]]

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Load the numpy file
# file_path = 'data/pos_data_log_pen.npy'
# pos_data = np.load(file_path)

# # Extract the x and y coordinates
# x_values = pos_data[1:, 0, 0]
# y_values = pos_data[1:, 0, 1]

# # Create a plot for the (x, y) data
# plt.figure(figsize=(10, 6))  # Adjust figure size
# plt.plot(x_values, y_values, 'b-', alpha=0.5, label='Position Data')  # 'b-' for a blue line with transparency

# # Add labels and a title
# plt.xlabel('X Coordinate', fontsize=12)
# plt.ylabel('Y Coordinate', fontsize=12)
# plt.title('Line Plot of Position Data (x, y)', fontsize=14)

# # Add gridlines for better readability
# plt.grid(True, linestyle='--', linewidth=0.5)

# # Add a legend
# plt.legend()

# # Draw a starting zone at (5,5)
# # Draw a circle with a radius of 0.2 around (5,5)
# start_x, start_y = 5, 5
# radius = 0.2
# circle = plt.Circle((start_x, start_y), radius, color='r', fill=False, linestyle='--', linewidth=2, label='Starting Zone')
# plt.gca().add_patch(circle)

# # Display the plot
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
from matplotlib.transforms import Affine2D
from scipy.ndimage import rotate
from matplotlib.legend_handler import HandlerPatch

plt.style.use('seaborn-v0_8')

# %%
plt.rcParams.update({
    'font.size': 24,
    'axes.titlesize': 16,     # Font size for titles
    'axes.labelsize': 16,     # Font size for x and y labels
    'xtick.labelsize': 12,    # Font size for x tick labels
    'ytick.labelsize': 12,    # Font size for y tick labels
    'legend.fontsize': 12     # Font size for legend
})
# List of data files to load
data_files = ['data/pos_data_cnn_no_dr.npy',
              'data/pos_data_cnn.npy']

# Define colors and labels for the plots
colors = ['#984ea3', '#377eb8']  # Adding a purple color
labels = ['CNN without Domain Randomization', 'CNN with Domain Randomization']

image_for_overlay = 'images/test_track_2_overlay.png'

plt.figure(figsize=(8, 6))  # Adjust figure size

for file_path, color, label in zip(data_files, colors, labels):
    # Load the numpy file
    pos_data = np.load(file_path)
    
    # Extract the x and y coordinates
    x_values = pos_data[1:, 0, 0, 0]
    y_values = pos_data[1:, 0, 0, 1]
    
    # Plot the (x, y) data
    plt.plot(x_values[255:], y_values[255:], color, alpha=0.8, label=label)

# Add the image overlay
img = mpimg.imread(image_for_overlay)
img = rotate(img, -90)
img_height, img_width = img.shape[:2]

# Calculate the aspect ratio
aspect_ratio = img_width / img_height

# Define the extent of the image overlay based on the aspect ratio and scale
scale_x = 8.15
scale_y = scale_x / aspect_ratio 
image_extent = [-scale_x, scale_x, -scale_y, scale_y]

print(image_extent)
plt.imshow(img, extent=image_extent, alpha=1, zorder=0)

# Add labels and a title
plt.xlabel(r'$x \, (m)$', fontsize=12)
plt.ylabel(r'$y \, (m)$', fontsize=12)
# plt.title('Line Plot of Position Data (x, y)', fontsize=14)

# Add gridlines for better readability
plt.grid(True, linestyle='--', linewidth=0.5)

# Draw a starting zone at (5,5)
# Draw a circle with a radius of 0.2 around (5,5)
start_x, start_y = 5, 5
radius = 0.2
circle = plt.Circle((start_x, start_y), radius, color='r', fill=True, linestyle='-', linewidth=2, label='Starting Zone')
plt.gca().add_patch(circle)

# Custom legend handler for the circle
class HandlerCircle(HandlerPatch):
    def create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans):
        circle = plt.Circle((0.5 * width - xdescent, 0.5 * height - ydescent), 0.2 * width, 
                            facecolor=orig_handle.get_facecolor(), edgecolor=orig_handle.get_edgecolor(),
                            lw=orig_handle.get_linewidth(), linestyle=orig_handle.get_linestyle(), transform=trans)
        return [circle]

# Add a legend below the plot
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.12), ncol=1, handler_map={circle: HandlerCircle()}, fontsize=12)

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig('images/no_dr_vs_dr_trajectory.svg', format='svg')
# plt.savefig('images/no_dr_vs_dr_trajectory.pdf', format='pdf')

# Display the plot
plt.show()
# Out:
# [-8.15, 8.15, -6.109975216852541, 6.109975216852541]

# %%
plt.rcParams.update({
    'font.size': 24,
    'axes.titlesize': 16,     # Font size for titles
    'axes.labelsize': 16,     # Font size for x and y labels
    'xtick.labelsize': 12,    # Font size for x tick labels
    'ytick.labelsize': 12,    # Font size for y tick labels
    'legend.fontsize': 12     # Font size for legend
})
# List of data files to load
data_files = ['data/pos_data_cnn_train_track_1.npy',
              'data/pos_data_cnn.npy']

# Define colors and labels for the plots
colors = ['#984ea3', '#377eb8']  # Adding a purple color
labels = ['CNN without Domain Randomization', 'CNN with Domain Randomization']

image_for_overlay = 'images/test_track_2_overlay.png'

plt.figure(figsize=(8, 6))  # Adjust figure size

for file_path, color, label in zip(data_files, colors, labels):
    # Load the numpy file
    pos_data = np.load(file_path)
    
    # Extract the x and y coordinates
    x_values = pos_data[1:, 0, 0, 0]
    y_values = pos_data[1:, 0, 0, 1]
    
    # Plot the (x, y) data
    plt.plot(x_values[255:], y_values[255:], color, alpha=0.8, label=label)

# Add the image overlay
img = mpimg.imread(image_for_overlay)
img = rotate(img, -90)
img_height, img_width = img.shape[:2]

# Calculate the aspect ratio
aspect_ratio = img_width / img_height

# Define the extent of the image overlay based on the aspect ratio and scale
scale_x = 8.15
scale_y = scale_x / aspect_ratio 
image_extent = [-scale_x, scale_x, -scale_y, scale_y]

print(image_extent)
plt.imshow(img, extent=image_extent, alpha=1, zorder=0)

# Add labels and a title
plt.xlabel(r'$x \, (m)$', fontsize=12)
plt.ylabel(r'$y \, (m)$', fontsize=12)
# plt.title('Line Plot of Position Data (x, y)', fontsize=14)

# Add gridlines for better readability
plt.grid(True, linestyle='--', linewidth=0.5)

# Draw a starting zone at (5,5)
# Draw a circle with a radius of 0.2 around (5,5)
start_x, start_y = 5, 5
radius = 0.2
circle = plt.Circle((start_x, start_y), radius, color='r', fill=True, linestyle='-', linewidth=2, label='Starting Zone')
plt.gca().add_patch(circle)

# Custom legend handler for the circle
class HandlerCircle(HandlerPatch):
    def create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans):
        circle = plt.Circle((0.5 * width - xdescent, 0.5 * height - ydescent), 0.2 * width, 
                            facecolor=orig_handle.get_facecolor(), edgecolor=orig_handle.get_edgecolor(),
                            lw=orig_handle.get_linewidth(), linestyle=orig_handle.get_linestyle(), transform=trans)
        return [circle]

# Add a legend below the plot
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.12), ncol=1, handler_map={circle: HandlerCircle()}, fontsize=12)

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig('images/no_dr_vs_dr_trajectory.svg', format='svg')
# plt.savefig('images/no_dr_vs_dr_trajectory.pdf', format='pdf')

# Display the plot
plt.show()
# Out:
# [-8.15, 8.15, -6.109975216852541, 6.109975216852541]

# %%
plt.rcParams.update({
    'font.size': 24,
    'axes.titlesize': 16,     # Font size for titles
    'axes.labelsize': 16,     # Font size for x and y labels
    'xtick.labelsize': 12,    # Font size for x tick labels
    'ytick.labelsize': 12,    # Font size for y tick labels
    'legend.fontsize': 12     # Font size for legend
})
# List of data files to load
data_files = ['data/pos_data_MLP_test_track_1_with_fixed_obstacles.npy',
              'data/pos_data_LSTM_test_track_1_with_fixed_obstacles.npy',
              'data/pos_data_CNN_test_track_1_with_fixed_obstacles.npy']

# Define colors and labels for the plots
colors = ['#e41a1c', '#4daf4a', '#377eb8']  # Colorblind-friendly palette
labels = ['MLP', 'LSTM', 'CNN']

image_for_overlay = 'images/test_track_1_obstacles.png'

plt.figure(figsize=(8, 6))  # Adjust figure size

for file_path, color, label in zip(data_files, colors, labels):
    # Load the numpy file
    pos_data = np.load(file_path)
    
    # Extract the x and y coordinates
    x_values = pos_data[1:, 0, 0, 0]
    y_values = pos_data[1:, 0, 0, 1]
    
    # Plot the (x, y) data
    plt.plot(x_values[:600], y_values[:600], color, alpha=0.8, label=label)

# Add the image overlay
img = mpimg.imread(image_for_overlay)
img = rotate(img, -90)
img_height, img_width = img.shape[:2]

# Calculate the aspect ratio
aspect_ratio = img_width / img_height

# Define the extent of the image overlay based on the aspect ratio and scale
scale_x = 8.15
scale_y = scale_x / aspect_ratio 
image_extent = [-scale_x, scale_x, -scale_y, scale_y]

print(image_extent)
plt.imshow(img, extent=image_extent, alpha=1, zorder=0)

# Add labels and a title
plt.xlabel(r'$x \, (m)$', fontsize=12)
plt.ylabel(r'$y \, (m)$', fontsize=12)
# plt.title('Line Plot of Position Data (x, y)', fontsize=14)

# Add gridlines for better readability
plt.grid(True, linestyle='--', linewidth=0.5)

# Draw a starting zone at (5,5)
# Draw a circle with a radius of 0.2 around (5,5)
start_x, start_y = 5, 5
radius = 0.2
circle = plt.Circle((start_x, start_y), radius, color='r', fill=True, linestyle='-', linewidth=2, label='Starting Zone')
plt.gca().add_patch(circle)

# Custom legend handler for the circle
class HandlerCircle(HandlerPatch):
    def create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans):
        circle = plt.Circle((0.5 * width - xdescent, 0.5 * height - ydescent), 0.2 * width, 
                            facecolor=orig_handle.get_facecolor(), edgecolor=orig_handle.get_edgecolor(),
                            lw=orig_handle.get_linewidth(), linestyle=orig_handle.get_linestyle(), transform=trans)
        return [circle]

# Add a legend below the plot
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.12), ncol=1, handler_map={circle: HandlerCircle()}, fontsize=12)

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig('images/test_track_1_trajectory_obstacles.svg', format='svg')
# plt.savefig('images/no_dr_vs_dr_trajectory.pdf', format='pdf')

# Display the plot
plt.show()
# Out:
# [-8.15, 8.15, -6.154081632653061, 6.154081632653061]

# %%
plt.rcParams.update({
    'font.size': 24,
    'axes.titlesize': 16,     # Font size for titles
    'axes.labelsize': 16,     # Font size for x and y labels
    'xtick.labelsize': 12,    # Font size for x tick labels
    'ytick.labelsize': 12,    # Font size for y tick labels
    'legend.fontsize': 12     # Font size for legend
})
# List of data files to load
data_files = ['data/pos_data_MLP_test_track_2_with_fixed_obstacles.npy',
              'data/pos_data_LSTM_test_track_2_with_fixed_obstacles.npy',
              'data/pos_data_CNN_test_track_2_with_fixed_obstacles.npy']

# Define colors and labels for the plots
colors = ['#e41a1c', '#4daf4a', '#377eb8']  # Colorblind-friendly palette
labels = ['MLP', 'LSTM', 'CNN']

image_for_overlay = 'images/test_track_2_obstacles.png'

plt.figure(figsize=(8, 6))  # Adjust figure size

for file_path, color, label in zip(data_files, colors, labels):
    # Load the numpy file
    pos_data = np.load(file_path)
    
    # Extract the x and y coordinates
    x_values = pos_data[1:, 0, 0, 0]
    y_values = pos_data[1:, 0, 0, 1]
    
    # Plot the (x, y) data
    plt.plot(x_values[:600], y_values[:600], color, alpha=0.8, label=label)

# Add the image overlay
img = mpimg.imread(image_for_overlay)
img = rotate(img, -90)
img_height, img_width = img.shape[:2]

# Calculate the aspect ratio
aspect_ratio = img_width / img_height

# Define the extent of the image overlay based on the aspect ratio and scale
scale_x = 8.15
scale_y = scale_x / aspect_ratio 
image_extent = [-scale_x, scale_x, -scale_y, scale_y]

print(image_extent)
plt.imshow(img, extent=image_extent, alpha=1, zorder=0)

# Add labels and a title
plt.xlabel(r'$x \, (m)$', fontsize=12)
plt.ylabel(r'$y \, (m)$', fontsize=12)
# plt.title('Line Plot of Position Data (x, y)', fontsize=14)

# Add gridlines for better readability
plt.grid(True, linestyle='--', linewidth=0.5)

# Draw a starting zone at (5,5)
# Draw a circle with a radius of 0.2 around (5,5)
start_x, start_y = 5, 5
radius = 0.2
circle = plt.Circle((start_x, start_y), radius, color='r', fill=True, linestyle='-', linewidth=2, label='Starting Zone')
plt.gca().add_patch(circle)

# Custom legend handler for the circle
class HandlerCircle(HandlerPatch):
    def create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans):
        circle = plt.Circle((0.5 * width - xdescent, 0.5 * height - ydescent), 0.2 * width, 
                            facecolor=orig_handle.get_facecolor(), edgecolor=orig_handle.get_edgecolor(),
                            lw=orig_handle.get_linewidth(), linestyle=orig_handle.get_linestyle(), transform=trans)
        return [circle]

# Add a legend below the plot
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.12), ncol=1, handler_map={circle: HandlerCircle()}, fontsize=12)

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig('images/test_track_1_trajectory_obstacles.svg', format='svg')
# plt.savefig('images/no_dr_vs_dr_trajectory.pdf', format='pdf')

# Display the plot
plt.show()
# Out:
# [-8.15, 8.15, -6.117606516290727, 6.117606516290727]

# %%
plt.rcParams.update({
    'font.size': 24,
    'axes.titlesize': 16,     # Font size for titles
    'axes.labelsize': 16,     # Font size for x and y labels
    'xtick.labelsize': 12,    # Font size for x tick labels
    'ytick.labelsize': 12,    # Font size for y tick labels
    'legend.fontsize': 12     # Font size for legend
})
# List of data files to load
data_files = ['data/pos_data_MLP_test_track_3_with_fixed_obstacles.npy',
              'data/pos_data_LSTM_test_track_3_with_fixed_obstacles.npy',
              'data/pos_data_CNN_test_track_3_with_fixed_obstacles.npy']

# Define colors and labels for the plots
colors = ['#e41a1c', '#4daf4a', '#377eb8']  # Colorblind-friendly palette
labels = ['MLP', 'LSTM', 'CNN']

image_for_overlay = 'images/test_track_3_obstacles.png'

plt.figure(figsize=(8, 6))  # Adjust figure size

# Variables to store the last points for each trajectory
last_points = []

for file_path, color, label in zip(data_files, colors, labels):
    # Load the numpy file
    pos_data = np.load(file_path)
    
    # Extract the x and y coordinates
    x_values = pos_data[1:, 0, 0, 0]
    y_values = pos_data[1:, 0, 0, 1]
    x = x_values[:500]
    y = y_values[:500]
    
    if label == 'CNN':
        x = x_values[60:560]
        y = y_values[60:560]
    
    # Plot the (x, y) data
    plt.plot(x, y, color, alpha=0.8, label=label)
    
    if label == 'MLP':
    # Store the last point
        last_points.append((x[-1], y[-1]+0.15, color, label))

# Plot the 'X' markers at the last (x, y) values
for x, y, color, label in last_points:
    plt.scatter(x, y, color=color, marker='X', s=100, zorder=5, label=f'{label} End')

# Add the image overlay
img = mpimg.imread(image_for_overlay)
img = rotate(img, -90)
img_height, img_width = img.shape[:2]

# Calculate the aspect ratio
aspect_ratio = img_width / img_height

# Define the extent of the image overlay based on the aspect ratio and scale
scale_x = 8.15
scale_y = scale_x / aspect_ratio 
image_extent = [-scale_x, scale_x, -scale_y, scale_y]

print(image_extent)
plt.imshow(img, extent=image_extent, alpha=1, zorder=0)

# Add labels and a title
plt.xlabel(r'$x \, (m)$', fontsize=12)
plt.ylabel(r'$y \, (m)$', fontsize=12)
# plt.title('Line Plot of Position Data (x, y)', fontsize=14)

# Add gridlines for better readability
plt.grid(True, linestyle='--', linewidth=0.5)

# Draw a starting zone at (5,5)
# Draw a circle with a radius of 0.2 around (5,5)
start_x, start_y = 5, 5
radius = 0.2
circle = plt.Circle((start_x, start_y), radius, color='r', fill=True, linestyle='-', linewidth=2, label='Starting Zone')
plt.gca().add_patch(circle)

# Custom legend handler for the circle
class HandlerCircle(HandlerPatch):
    def create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans):
        circle = plt.Circle((0.5 * width - xdescent, 0.5 * height - ydescent), 0.2 * width, 
                            facecolor=orig_handle.get_facecolor(), edgecolor=orig_handle.get_edgecolor(),
                            lw=orig_handle.get_linewidth(), linestyle=orig_handle.get_linestyle(), transform=trans)
        return [circle]

# Add a legend below the plot
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.12), ncol=1, handler_map={circle: HandlerCircle()}, fontsize=12)

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig('images/test_track_1_trajectory_obstacles.svg', format='svg')
# plt.savefig('images/no_dr_vs_dr_trajectory.pdf', format='pdf')

# Display the plot
plt.show()
# Out:
# [-8.15, 8.15, -6.147588978185993, 6.147588978185993]

# %%
from matplotlib.gridspec import GridSpec

plt.style.use('seaborn-v0_8')
plt.rcParams.update({
    'font.size': 24,
    'axes.titlesize': 16,     # Font size for titles
    'axes.labelsize': 16,     # Font size for x and y labels
    'xtick.labelsize': 12,    # Font size for x tick labels
    'ytick.labelsize': 12,    # Font size for y tick labels
    'legend.fontsize': 12     # Font size for legend
})

# Function to create a plot for each track
def create_plot(ax, data_files, image_for_overlay, labels, colors, title):
    # Variables to store the last points for each trajectory
    last_points = []

    for file_path, color, label in zip(data_files, colors, labels):
        # Load the numpy file
        pos_data = np.load(file_path)

        # Extract the x and y coordinates
        x_values = pos_data[1:, 0, 0, 0]
        y_values = pos_data[1:, 0, 0, 1]
        x = x_values[:500]
        y = y_values[:500]

        if label == 'CNN':
            x = x_values[60:560]
            y = y_values[60:560]

        # Plot the (x, y) data
        ax.plot(x, y, color, alpha=0.8, label=label)

        # Store the last point
        last_points.append((x[-1], y[-1], color, label))

    # Plot the 'X' markers at the last (x, y) values
    for x, y, color, label in last_points:
        ax.scatter(x, y, color=color, marker='X', s=100, zorder=5, label=f'{label} End')

    # Add the image overlay
    img = mpimg.imread(image_for_overlay)
    img = rotate(img, -90)
    img_height, img_width = img.shape[:2]

    # Calculate the aspect ratio
    aspect_ratio = img_width / img_height

    # Define the extent of the image overlay based on the aspect ratio and scale
    scale_x = 8.15
    scale_y = scale_x / aspect_ratio 
    image_extent = [-scale_x, scale_x, -scale_y, scale_y]

    ax.imshow(img, extent=image_extent, alpha=1, zorder=0)

    # Add labels and a title
    ax.set_xlabel(r'$x \, (m)$', fontsize=12)
    ax.set_ylabel(r'$y \, (m)$', fontsize=12)
    ax.set_title(title, fontsize=14)

    # Add gridlines for better readability
    ax.grid(True, linestyle='--', linewidth=0.5)

    # Draw a starting zone at (5,5)
    start_x, start_y = 5, 5
    radius = 0.2
    circle = plt.Circle((start_x, start_y), radius, color='r', fill=True, linestyle='-', linewidth=2, label='Starting Zone')
    ax.add_patch(circle)

# Custom legend handler for the circle
class HandlerCircle(HandlerPatch):
    def create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans):
        circle = plt.Circle((0.5 * width - xdescent, 0.5 * height - ydescent), 0.2 * width, 
                            facecolor=orig_handle.get_facecolor(), edgecolor=orig_handle.get_edgecolor(),
                            lw=orig_handle.get_linewidth(), linestyle=orig_handle.get_linestyle(), transform=trans)
        return [circle]

# Create a figure with GridSpec
fig = plt.figure(figsize=(16, 12))
gs = GridSpec(3, 2, figure=fig)

# Plot for Track 1
data_files_1 = ['data/pos_data_MLP_test_track_1_with_fixed_obstacles.npy',
                'data/pos_data_LSTM_test_track_1_with_fixed_obstacles.npy',
                'data/pos_data_CNN_test_track_1_with_fixed_obstacles.npy']
ax1 = fig.add_subplot(gs[0, 0])
create_plot(ax1, data_files_1, 'images/test_track_1_obstacles.png', labels, colors, 'Test Track 1')

# Plot for Track 2
data_files_2 = ['data/pos_data_MLP_test_track_2_with_fixed_obstacles.npy',
                'data/pos_data_LSTM_test_track_2_with_fixed_obstacles.npy',
                'data/pos_data_CNN_test_track_2_with_fixed_obstacles.npy']
ax2 = fig.add_subplot(gs[0, 1])
create_plot(ax2, data_files_2, 'images/test_track_2_obstacles.png', labels, colors, 'Test Track 2')

# Plot for Track 3
data_files_3 = ['data/pos_data_MLP_test_track_3_with_fixed_obstacles.npy',
                'data/pos_data_LSTM_test_track_3_with_fixed_obstacles.npy',
                'data/pos_data_CNN_test_track_3_with_fixed_obstacles.npy']
ax3 = fig.add_subplot(gs[1, :])
create_plot(ax3, data_files_3, 'images/test_track_3_obstacles.png', labels, colors, 'Test Track 3')

# Create a centered legend below the plots
handles, labels = ax3.get_legend_handles_labels()
fig.legend(handles[:3], labels[:3], loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3, fontsize=12)
fig.legend(handles[3:], labels[3:], loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, handler_map={circle: HandlerCircle()}, fontsize=12)

# Adjust layout and save the figure
plt.tight_layout(rect=[0, 0.1, 1, 1])
plt.savefig('images/test_tracks_combined.svg', format='svg')
# plt.savefig('images/test_tracks_combined.pdf', format='pdf')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
from matplotlib.legend_handler import HandlerPatch
from scipy.ndimage import rotate

plt.style.use('seaborn-v0_8')
plt.rcParams.update({
    'font.size': 24,
    'axes.titlesize': 16,     # Font size for titles
    'axes.labelsize': 16,     # Font size for x and y labels
    'xtick.labelsize': 12,    # Font size for x tick labels
    'ytick.labelsize': 12,    # Font size for y tick labels
    'legend.fontsize': 12     # Font size for legend
})

# Function to create a plot for each track
def create_plot(ax, data_files, image_for_overlay, labels, colors, title):
    # Variables to store the last points for each trajectory
    last_points = []

    for file_path, color, label in zip(data_files, colors, labels):
        # Load the numpy file
        pos_data = np.load(file_path)

        # Extract the x and y coordinates
        x_values = pos_data[1:, 0, 0, 0]
        y_values = pos_data[1:, 0, 0, 1]
        x = x_values[:500]
        y = y_values[:500]

        if label == 'CNN':
            x = x_values[60:560]
            y = y_values[60:560]

        # Plot the (x, y) data
        ax.plot(x, y, color, alpha=0.8, label=label)

        # Store the last point
        last_points.append((x[-1], y[-1], color, label))

    # Plot the 'X' markers at the last (x, y) values
    for x, y, color, label in last_points:
        ax.scatter(x, y, color=color, marker='X', s=100, zorder=5, label=f'{label} End')

    # Add the image overlay
    img = mpimg.imread(image_for_overlay)
    img = rotate(img, -90)
    img_height, img_width = img.shape[:2]

    # Calculate the aspect ratio
    aspect_ratio = img_width / img_height

    # Define the extent of the image overlay based on the aspect ratio and scale
    scale_x = 8.15
    scale_y = scale_x / aspect_ratio 
    image_extent = [-scale_x, scale_x, -scale_y, scale_y]

    ax.imshow(img, extent=image_extent, alpha=1, zorder=0)

    # Add labels and a title
    ax.set_xlabel(r'$x \, (m)$', fontsize=12)
    ax.set_ylabel(r'$y \, (m)$', fontsize=12)
    ax.set_title(title, fontsize=14)

    # Add gridlines for better readability
    ax.grid(True, linestyle='--', linewidth=0.5)

    # Draw a starting zone at (5,5)
    start_x, start_y = 5, 5
    radius = 0.2
    circle = plt.Circle((start_x, start_y), radius, color='r', fill=True, linestyle='-', linewidth=2, label='Starting Zone')
    ax.add_patch(circle)

# Custom legend handler for the circle
class HandlerCircle(HandlerPatch):
    def create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans):
        circle = plt.Circle((0.5 * width - xdescent, 0.5 * height - ydescent), 0.2 * width, 
                            facecolor=orig_handle.get_facecolor(), edgecolor=orig_handle.get_edgecolor(),
                            lw=orig_handle.get_linewidth(), linestyle=orig_handle.get_linestyle(), transform=trans)
        return [circle]

# Create a figure with GridSpec
fig = plt.figure(figsize=(16, 12), constrained_layout=True)
gs = fig.add_gridspec(3, 2)

# Plot for Track 1
data_files_1 = ['data/pos_data_MLP_test_track_1_with_fixed_obstacles.npy',
                'data/pos_data_LSTM_test_track_1_with_fixed_obstacles.npy',
                'data/pos_data_CNN_test_track_1_with_fixed_obstacles.npy']
ax1 = fig.add_subplot(gs[0, 0])
create_plot(ax1, data_files_1, 'images/test_track_1_obstacles.png', labels, colors, 'Test Track 1')

# Plot for Track 2
data_files_2 = ['data/pos_data_MLP_test_track_2_with_fixed_obstacles.npy',
                'data/pos_data_LSTM_test_track_2_with_fixed_obstacles.npy',
                'data/pos_data_CNN_test_track_2_with_fixed_obstacles.npy']
ax2 = fig.add_subplot(gs[0, 1])
create_plot(ax2, data_files_2, 'images/test_track_2_obstacles.png', labels, colors, 'Test Track 2')

# Plot for Track 3
data_files_3 = ['data/pos_data_MLP_test_track_3_with_fixed_obstacles.npy',
                'data/pos_data_LSTM_test_track_3_with_fixed_obstacles.npy',
                'data/pos_data_CNN_test_track_3_with_fixed_obstacles.npy']
ax3 = fig.add_subplot(gs[1, :])
create_plot(ax3, data_files_3, 'images/test_track_3_obstacles.png', labels, colors, 'Test Track 3')

# Create a centered legend below the plots
handles, labels = ax3.get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', bbox_to_anchor=(0.5, 0.05), ncol=3, handler_map={plt.Circle: HandlerCircle()}, fontsize=12)

# Adjust layout and save the figure
plt.tight_layout(rect=[0, 0.1, 1, 1])
plt.savefig('images/test_tracks_combined.svg', format='svg')
# plt.savefig('images/test_tracks_combined.pdf', format='pdf')

# Display the plot
plt.show()
# Out:
# C:\Users\lvind\AppData\Local\Temp\ipykernel_23112\3514503228.py:113: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(rect=[0, 0.1, 1, 1])

# %%
plt.rcParams.update({
    'font.size': 24,
    'axes.titlesize': 16,     # Font size for titles
    'axes.labelsize': 16,     # Font size for x and y labels
    'xtick.labelsize': 12,    # Font size for x tick labels
    'ytick.labelsize': 12,    # Font size for y tick labels
    'legend.fontsize': 12     # Font size for legend
})

# Function to create a plot for each track
def create_plot(ax, data_files, image_for_overlay, labels, colors, title):
    # Variables to store the last points for each trajectory
    last_points = []

    for file_path, color, label in zip(data_files, colors, labels):
        # Load the numpy file
        pos_data = np.load(file_path)

        # Extract the x and y coordinates
        x_values = pos_data[1:, 0, 0, 0]
        y_values = pos_data[1:, 0, 0, 1]
        x = x_values[:500]
        y = y_values[:500]

        if label == 'CNN':
            x = x_values[60:560]
            y = y_values[60:560]

        # Plot the (x, y) data
        ax.plot(x, y, color, alpha=0.8, label=label)

        # Store the last point
        last_points.append((x[-1], y[-1], color, label))

    # Plot the 'X' markers at the last (x, y) values
    for x, y, color, label in last_points:
        ax.scatter(x, y, color=color, marker='X', s=100, zorder=5, label=f'{label} End')

    # Add the image overlay
    img = mpimg.imread(image_for_overlay)
    img = rotate(img, -90)
    img_height, img_width = img.shape[:2]

    # Calculate the aspect ratio
    aspect_ratio = img_width / img_height

    # Define the extent of the image overlay based on the aspect ratio and scale
    scale_x = 8.15
    scale_y = scale_x / aspect_ratio 
    image_extent = [-scale_x, scale_x, -scale_y, scale_y]

    ax.imshow(img, extent=image_extent, alpha=1, zorder=0)

    # Add labels and a title
    ax.set_xlabel(r'$x \, (m)$', fontsize=12)
    ax.set_ylabel(r'$y \, (m)$', fontsize=12)
    ax.set_title(title, fontsize=14)

    # Add gridlines for better readability
    ax.grid(True, linestyle='--', linewidth=0.5)

    # Draw a starting zone at (5,5)
    start_x, start_y = 5, 5
    radius = 0.2
    circle = plt.Circle((start_x, start_y), radius, color='r', fill=True, linestyle='-', linewidth=2, label='Starting Zone')
    ax.add_patch(circle)

# Custom legend handler for the circle
class HandlerCircle(HandlerPatch):
    def create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans):
        circle = plt.Circle((0.5 * width - xdescent, 0.5 * height - ydescent), 0.2 * width, 
                            facecolor=orig_handle.get_facecolor(), edgecolor=orig_handle.get_edgecolor(),
                            lw=orig_handle.get_linewidth(), linestyle=orig_handle.get_linestyle(), transform=trans)
        return [circle]

# Create a figure with GridSpec
fig = plt.figure(figsize=(12, 9), constrained_layout=True) # True size is (19, 12)
gs = fig.add_gridspec(2, 2)

# Plot for Track 1
data_files_1 = ['data/pos_data_MLP_test_track_1_with_fixed_obstacles.npy',
                'data/pos_data_LSTM_test_track_1_with_fixed_obstacles.npy',
                'data/pos_data_CNN_test_track_1_with_fixed_obstacles.npy']
ax1 = fig.add_subplot(gs[0, 0])
create_plot(ax1, data_files_1, 'images/test_track_1_obstacles.png', labels, colors, 'Test Track 1')

# Plot for Track 2
data_files_2 = ['data/pos_data_MLP_test_track_2_with_fixed_obstacles.npy',
                'data/pos_data_LSTM_test_track_2_with_fixed_obstacles.npy',
                'data/pos_data_CNN_test_track_2_with_fixed_obstacles.npy']
ax2 = fig.add_subplot(gs[0, 1])
create_plot(ax2, data_files_2, 'images/test_track_2_obstacles.png', labels, colors, 'Test Track 2')

# Plot for Track 3
data_files_3 = ['data/pos_data_MLP_test_track_3_with_fixed_obstacles.npy',
                'data/pos_data_LSTM_test_track_3_with_fixed_obstacles.npy',
                'data/pos_data_CNN_test_track_3_with_fixed_obstacles.npy']
ax3 = fig.add_subplot(gs[1, 0])
create_plot(ax3, data_files_3, 'images/test_track_3_obstacles.png', labels, colors, 'Test Track 3')

# Create an empty subplot for the legend
ax_legend = fig.add_subplot(gs[1, 1])
ax_legend.axis('off')

# Create the legend in the dedicated subplot
handles, labels = ax3.get_legend_handles_labels()
legend = ax_legend.legend(handles, labels, loc='center', handler_map={plt.Circle: HandlerCircle()}, fontsize=12)

# Save the figure
plt.savefig('images/test_tracks_combined.svg', format='svg')
# plt.savefig('images/test_tracks_combined.pdf', format='pdf')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
from matplotlib.legend_handler import HandlerPatch
from scipy.ndimage import rotate

plt.style.use('seaborn-v0_8')
plt.rcParams.update({
    'font.size': 24,
    'axes.titlesize': 16,     # Font size for titles
    'axes.labelsize': 16,     # Font size for x and y labels
    'xtick.labelsize': 12,    # Font size for x tick labels
    'ytick.labelsize': 12,    # Font size for y tick labels
    'legend.fontsize': 12     # Font size for legend
})

# Function to create a plot for each track
def create_plot(data_files, image_for_overlay, labels, colors, title):
    fig, ax = plt.subplots(figsize=(10, 8))
    
    # Variables to store the last points for each trajectory
    last_points = []

    for file_path, color, label in zip(data_files, colors, labels):
        # Load the numpy file
        pos_data = np.load(file_path)

        # Extract the x and y coordinates
        x_values = pos_data[1:, 0, 0, 0]
        y_values = pos_data[1:, 0, 0, 1]
        x = x_values[:500]
        y = y_values[:500]

        if label == 'CNN':
            x = x_values[60:560]
            y = y_values[60:560]

        # Plot the (x, y) data
        ax.plot(x, y, color, alpha=0.8, label=label)

        # Store the last point
        last_points.append((x[-1], y[-1], color, label))

    # Plot the 'X' markers at the last (x, y) values
    for x, y, color, label in last_points:
        ax.scatter(x, y, color=color, marker='X', s=100, zorder=5, label=f'{label} End')

    # Add the image overlay
    img = mpimg.imread(image_for_overlay)
    img = rotate(img, -90)
    img_height, img_width = img.shape[:2]

    # Calculate the aspect ratio
    aspect_ratio = img_width / img_height

    # Define the extent of the image overlay based on the aspect ratio and scale
    scale_x = 8.15
    scale_y = scale_x / aspect_ratio 
    image_extent = [-scale_x, scale_x, -scale_y, scale_y]

    ax.imshow(img, extent=image_extent, alpha=1, zorder=0)

    # Add labels and a title
    ax.set_xlabel(r'$x \, (m)$', fontsize=12)
    ax.set_ylabel(r'$y \, (m)$', fontsize=12)
    ax.set_title(title, fontsize=14)

    # Add gridlines for better readability
    ax.grid(True, linestyle='--', linewidth=0.5)

    # Draw a starting zone at (5,5)
    start_x, start_y = 5, 5
    radius = 0.2
    circle = plt.Circle((start_x, start_y), radius, color='r', fill=True, linestyle='-', linewidth=2, label='Starting Zone')
    ax.add_patch(circle)

    # Custom legend handler for the circle
    class HandlerCircle(HandlerPatch):
        def create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans):
            circle = plt.Circle((0.5 * width - xdescent, 0.5 * height - ydescent), 0.2 * width, 
                                facecolor=orig_handle.get_facecolor(), edgecolor=orig_handle.get_edgecolor(),
                                lw=orig_handle.get_linewidth(), linestyle=orig_handle.get_linestyle(), transform=trans)
            return [circle]

    # Create the legend
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5), handler_map={plt.Circle: HandlerCircle()}, fontsize=12)

    # Adjust layout and save the figure
    plt.tight_layout()
    plt.show()

# Plot for Track 1
data_files_1 = ['data/pos_data_MLP_test_track_1_with_fixed_obstacles.npy',
                'data/pos_data_LSTM_test_track_1_with_fixed_obstacles.npy',
                'data/pos_data_CNN_test_track_1_with_fixed_obstacles.npy']
create_plot(data_files_1, 'images/test_track_1_obstacles.png', ['MLP', 'LSTM', 'CNN'], ['r', 'g', 'b'], 'Test Track 1')

# Plot for Track 2
data_files_2 = ['data/pos_data_MLP_test_track_2_with_fixed_obstacles.npy',
                'data/pos_data_LSTM_test_track_2_with_fixed_obstacles.npy',
                'data/pos_data_CNN_test_track_2_with_fixed_obstacles.npy']
create_plot(data_files_2, 'images/test_track_2_obstacles.png', ['MLP', 'LSTM', 'CNN'], ['r', 'g', 'b'], 'Test Track 2')

# Plot for Track 3
data_files_3 = ['data/pos_data_MLP_test_track_3_with_fixed_obstacles.npy',
                'data/pos_data_LSTM_test_track_3_with_fixed_obstacles.npy',
                'data/pos_data_CNN_test_track_3_with_fixed_obstacles.npy']
create_plot(data_files_3, 'images/test_track_3_obstacles.png', ['MLP', 'LSTM', 'CNN'], ['r', 'g', 'b'], 'Test Track 3')

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
from matplotlib.legend_handler import HandlerPatch
from scipy.ndimage import rotate

plt.style.use('seaborn-v0_8')
plt.rcParams.update({
    'font.size': 24,
    'axes.titlesize': 16,     # Font size for titles
    'axes.labelsize': 16,     # Font size for x and y labels
    'xtick.labelsize': 12,    # Font size for x tick labels
    'ytick.labelsize': 12,    # Font size for y tick labels
    'legend.fontsize': 12     # Font size for legend
})

# Function to create a plot for each track
def create_plot(data_files, image_for_overlay, labels, colors, title, step_range, end_markers):
    fig, ax = plt.subplots(figsize=(8, 6))
    
    # Variables to store the last points for each trajectory
    last_points = []

    for file_path, color, label in zip(data_files, colors, labels):
        # Load the numpy file
        pos_data = np.load(file_path)

        # Extract the x and y coordinates
        x_values = pos_data[1:, 0, 0, 0]
        y_values = pos_data[1:, 0, 0, 1]

        _step_range = step_range[label]
        x = x_values[_step_range[0]:_step_range[1]]
        y = y_values[_step_range[0]:_step_range[1]]


        # x = x_values[step_range[0]:step_range[1]]
        # y = y_values[step_range[0]:step_range[1]]

        # x = x_values[:500]
        # y = y_values[:500]

        # if label == 'CNN':
        #     x = x_values[60:560]
        #     y = y_values[60:560]

        # Plot the (x, y) data
        ax.plot(x, y, color, alpha=0.8, label=label)

        # Store the last point
        # last_points.append((x[-1], y[-1], color, label))
        # Store the last point
        if end_markers[label]:
            last_points.append((x[-1], y[-1], color, label))

    # Plot the 'X' markers at the last (x, y) values
    for x, y, color, label in last_points:
        ax.scatter(x, y, color=color, marker='X', s=100, zorder=5)
    
    # Plot a black 'X' marker for the legend
    ax.scatter([], [], color='k', marker='X', s=100, label='Collision')

    # Add the image overlay
    img = mpimg.imread(image_for_overlay)
    img = rotate(img, -90)
    img_height, img_width = img.shape[:2]

    # Calculate the aspect ratio
    aspect_ratio = img_width / img_height

    # Define the extent of the image overlay based on the aspect ratio and scale
    scale_x = 8.15
    scale_y = scale_x / aspect_ratio 
    image_extent = [-scale_x, scale_x, -scale_y, scale_y]

    ax.imshow(img, extent=image_extent, alpha=1, zorder=0)

    # Add labels and a title
    # ax.set_xlabel(r'$x \, (m)$', fontsize=12)
    # ax.set_ylabel(r'$y \, (m)$', fontsize=12)
    # ax.set_title(title, fontsize=14)

    # Add gridlines for better readability
    ax.grid(True, linestyle='--', linewidth=0.5)

    # Draw a starting zone at (5,5)
    start_x, start_y = 5, 5
    radius = 0.2
    circle = plt.Circle((start_x, start_y), radius, color='r', fill=True, linestyle='-', linewidth=2, label='Starting Zone')
    ax.add_patch(circle)

    # Custom legend handler for the circle
    class HandlerCircle(HandlerPatch):
        def create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans):
            circle = plt.Circle((0.5 * width - xdescent, 0.5 * height - ydescent), 0.2 * width, 
                                facecolor=orig_handle.get_facecolor(), edgecolor=orig_handle.get_edgecolor(),
                                lw=orig_handle.get_linewidth(), linestyle=orig_handle.get_linestyle(), transform=trans)
            return [circle]

    # Create the legend
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5), handler_map={plt.Circle: HandlerCircle()}, fontsize=12)

    # Adjust layout and save the figure
    plt.tight_layout()
    plt.show()

colors = ['#e41a1c', '#4daf4a', '#377eb8']

# %%
# Plot for Track 1
data_files_1 = ['data/pos_data_MLP_test_track_1_with_fixed_obstacles.npy',
                'data/pos_data_LSTM_test_track_1_with_fixed_obstacles.npy',
                'data/pos_data_CNN_test_track_1_with_fixed_obstacles.npy']


# Dictionary to store the step ranges for each model
step_ranges1 = {
    'MLP': [0, 570],
    'LSTM': [0, 575],
    'CNN': [0, 700]
}

end_markers1 = {
    'MLP': True,
    'LSTM': True,
    'CNN': False
}


create_plot(data_files_1, 'images/test_track_1_obstacles.png', ['MLP', 'LSTM', 'CNN'], colors, 'Test Track 1', step_ranges1, end_markers1)

# %%
# Plot for Track 2
data_files_2 = ['data/pos_data_MLP_test_track_2_with_fixed_obstacles.npy',
                'data/pos_data_LSTM_test_track_2_with_fixed_obstacles.npy',
                'data/pos_data_CNN_test_track_2_with_fixed_obstacles.npy']


step_ranges2 = {
    'MLP': [0, 365],
    'LSTM': [0, 460],
    'CNN': [0, 70]
}

end_markers2 = {
    'MLP': True,
    'LSTM': True,
    'CNN': False
}


create_plot(data_files_2, 'images/test_track_2_obstacles.png', ['MLP', 'LSTM', 'CNN'], colors, 'Test Track 2', step_ranges2, end_markers2)

# %%
# Plot for Track 3
data_files_3 = ['data/pos_data_MLP_test_track_3_with_fixed_obstacles.npy',
                'data/pos_data_LSTM_test_track_3_with_fixed_obstacles.npy',
                'data/pos_data_CNN_test_track_3_with_fixed_obstacles.npy']
create_plot(data_files_3, 'images/test_track_3_obstacles.png', ['MLP', 'LSTM', 'CNN'], colors, 'Test Track 3')
